# %% [markdown]
# # Basic Distribution Analysis With Gun Violence

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Data Analysis using data.world dataset:

# %%
# load csv
massDf = pd.read_csv('./Data/gun-violence-database/mass_shootings_all.csv');
massDf
# Out:
#          Incident Date           State                City Or County  \
# 0    November 26, 2016        Illinois                       Chicago
# 1    November 25, 2016       Louisiana                   New Orleans
# 2    November 24, 2016        Kentucky                    Louisville
# 3    November 24, 2016        New York                        Albany
# 4    November 23, 2016     Mississippi                  Olive Branch
# 5    November 22, 2016         Florida                     Clewiston
# 6    November 18, 2016        Illinois                       Chicago
# 7    November 17, 2016       Tennessee                     Dyersburg
# 8    November 13, 2016      California                     San Diego
# 9    November 13, 2016         Florida                  Jacksonville
# 10   November 13, 2016         Florida                       Orlando
# 11   November 13, 2016           Texas                   San Antonio
# 12   November 12, 2016     Connecticut                    Bridgeport
# ...

# %%
deaths_df = massDf['# Killed'];
# deaths_df; #verify
# deaths_df.val.max
# Out:
# <bound method Series.max of 0      1
# 1      0
# 2      2
# 3      1
# 4      0
# 5      1
# 6      0
# 7      1
# 8      3
# 9      3
# 10     0
# 11     0
# 12     0
# 13     1
# 14     1
# 15     0
# 16     1
# 17     1
# 18     0
# 19     0
# 20     1
# 21     0
# 22     0
# 23     0
# 24     0
# 25     0
# 26     2
# 27     1
# 28     1
# 29     0
#       ..
# 470    0
# 471    1
# 472    0
# 473    1
# 474    0
# 475    1
# 476    1
# 477    0
# 478    2
# 479    1
# 480    8
# 481    4
# 482    0
# 483    1
# 484    0
# 485    0
# 486    0
# 487    1
# 488    0
# 489    0
# 490    0
# 491    0
# 492    0
# 493    2
# 494    0
# 495    0
# 496    2
# 497    3
# 498    5
# 499    1
# Name: # Killed, Length: 500, dtype: int64>

# %%
# Simple histogram of mass shooting in America by amount
n, bins, patches = plt.hist(deaths_df.values, 50, normed=1, facecolor='green', alpha=0.75);
plt.xlabel('Deaths');
plt.ylabel('Probablity');
plt.show()
